# %%
import pickle 

with open('logestic_regression_best_model.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
from matplotlib import pyplot as plt
img = plt.imread("8.png")[:,:,0]

# %%
plt.imshow(img)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_img = scaler.fit_transform(img.reshape(1, -1))

# %%
pred = model.predict(scaled_img)

pred[0]
# Out:
# '8'
